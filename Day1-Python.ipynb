# %%
Print('hello')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2674531823.py in <cell line: 0>()
# ----> 1 Print('hello')
#
# NameError: name 'Print' is not defined

# %%
print('hello')
# Out:
# hello

# %%
print("hi")
name = "aryan"
print('my name is '+name)
name =5
print(name)
# Out:
# hi
# my name is aryan
# 5

# %%
a = 1
print(type(a))
a = 3.1432
print(type(a))
a = 'mango'
print(type(a))
a = True
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name = input("Enter your name")
print(name)
# Out:
# Enter your nameAryan
# Aryan

# %%
name = input("Enter your name")
print(name)
if name.isdigit():
  name = int(name) + 1
  print(name)
else:
  print("Invalid input. Please enter a number.")
# Out:
# Enter your namename
# name
# Invalid input. Please enter a number.

# %%
name = input('Enter a value')
print (name + "name")
# Out:
# Enter a value43
# 43name

# %%
name = input ('enter a name')
print(name + 43)
# Out:
# enter a namearyan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1268543492.py in <cell line: 0>()
#       1 name = input ('enter a name')
# ----> 2 print(name + 43)
#
# TypeError: can only concatenate str (not "int") to str

# %%
from re import M
#hi
''' hello y name is  aryN '''
# Out:
# ' hello y name is  aryN '

# %%
print("hello")
print("I am a maths bot")
bots_name = "Jarvis"
print("My name is " + bots_name)
print("let's add some numbers")
input1 = input("Number 1>")
input2 = input("Number 2>")
number1 = int(input1)
number2 = int(input2)
result = number1 + number2
output = str(result)
print(input1 + "+" + input2 + "=" + output)
# Out:
# hello
# I am a maths bot
# My name is Jarvis
# let's add some numbers
# Number 1>2
# Number 2>3
# 2+3=5

# %%
#HW ASSIGNMENT DAY 1
#create your own bot that will ask your name and based on the interest, you give the amount. givep*t*r

# %%
#Solution
name = input("what is your name?")
principal = 1000
rate = 5.5
time = 2
print("Hii "+name +", I am your interest calculator bot PeePee!\n")
print("Based on the current data given to me, \nPrincipal = "+str(principal) + "\nRate = "+str(rate) +"\nTime = "+str(time) +"\n\nYour amount is "+str((principal*rate*time)/100))
# Out:
# what is your name?Aryan
# Hii Aryan, I am your interest calculator bot PeePee!!
#
# Based on the current data given to me,
# Principal = 1000
# Rate = 5.5
# Time = 2
#
# Your amount is 110.0
